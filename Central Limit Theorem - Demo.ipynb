# %% [markdown]
# # Cell below loads the library for necessary function

# %%
# %matplotlib inline
import numpy as np
import seaborn as sns

# %% [markdown]
# # different distribution plots

# %%
different_kind_of_distrbutions = ["beta","binomial","chisquare","dirichlet","exponential"]

# %%
#sns.distplot(np.random.beta(10, 2,10000))
sns.distplot(np.random.binomial(10, .5,10000))

# %% [markdown]
# # Central Limit Theorem

# %%
sampled_data = []
number_of_samples = np.random.randint(300,1000,1)[0]
for sample_run in range(0,10000):
    
    #sampled_data.append(np.random.beta(10, 2,number_of_samples).mean())
    sampled_data.append(np.random.binomial(10, .5,number_of_samples).mean())

sns.distplot(sampled_data)
